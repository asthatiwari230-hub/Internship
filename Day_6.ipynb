# %%
import pandas as pd
df=pd.read_csv("record.csv")
print(df)
# Out:
#            Name  English  Mathematics  Science  Social Studies  Computer
# 0  Aarav Sharma       85           92       78              88        95
# 1   Priya Verma       90           87       91              85        89
# 2   Rahul Singh       76           81       74              79        83
# 3  Ananya Gupta       95           93       96              90        98
# 4  Vikram Yadav       68           75       72              70        77
# 5   Neha Mishra       88           84       89              92        86
# 6  Aditya Kumar       79           86       80              75        82
# 7   Sneha Patel       92           89       94              91        93
# 8   Rohan Mehta       73           78       85              80        76
# 9   Kavya Joshi       86           91       88              87        90

# %%
df["Hindi"]=([97,67,87,97,67,87,86,54,87,98])
print(df)
# Out:
#            Name  English  Mathematics  Science  Social Studies  Computer  \
# 0  Aarav Sharma       85           92       78              88        95
# 1   Priya Verma       90           87       91              85        89
# 2   Rahul Singh       76           81       74              79        83
# 3  Ananya Gupta       95           93       96              90        98
# 4  Vikram Yadav       68           75       72              70        77
# 5   Neha Mishra       88           84       89              92        86
# 6  Aditya Kumar       79           86       80              75        82
# 7   Sneha Patel       92           89       94              91        93
# 8   Rohan Mehta       73           78       85              80        76
# 9   Kavya Joshi       86           91       88              87        90
#
#    Hindi
# 0     97
# 1     67
# 2     87
# 3     97
# 4     67
# 5     87
# 6     86
# 7     54
# 8     87
# 9     98

# %%
df=pd.read_csv("employee.csv")
print(df)
# Out:
#     ID    Name Department   Salary
# 0    1   Aarav         HR  45000.0
# 1    2   Priya         IT  55000.0
# 2    3   Rahul    Finance  60000.0
# 3    4  Ananya  Marketing  50000.0
# 4    5  Vikram      Sales      NaN
# 5    6    Neha         IT  65000.0
# 6    7   Rohan         HR  48000.0
# 7    8   Sneha    Finance  70000.0
# 8    9    Amit  Marketing      NaN
# 9   10   Pooja      Sales  58000.0
# 10  11   Karan         IT  62000.0
# 11  12    Isha         HR  47000.0
# 12  13   Arjun    Finance  75000.0
# 13  14   Meera  Marketing  51000.0
# 14  15     NaN      Sales  59000.0
# 15  16   Kavya         IT  68000.0
# 16  17  Suresh         HR  49000.0
# 17  18    Riya    Finance  72000.0
# 18  19  Manish  Marketing      NaN
# 19  20   Tanya      Sales  56000.0

# %%
a=df.groupby("Department")["Salary"].max()
print(a)
# Out:
# Department
# Finance      75000.0
# HR           49000.0
# IT           68000.0
# Marketing    51000.0
# Sales        59000.0
# Name: Salary, dtype: float64

# %%
df=pd.read_csv("employee_data.csv")
print(df)
# Out:
#    employee_id             name   department   salary
# 0          101      Alice Smith  Engineering  85000.0
# 1          102        Bob Jones    Marketing  62000.0
# 2          103    Charlie Brown      Finance      0.0
# 3          104     Diana Prince          NaN  75000.0
# 4          105      Evan Wright  Engineering  92000.0
# 5          106  Fiona Gallagher           HR  58000.0
# 6          107     George Clark    Marketing      NaN
# 7          108    Hannah Abbott      Finance      0.0
# 8          109      Ian Malcolm        Sales  81000.0
# 9          110    Julia Roberts           HR  67000.0

# %%
print(df.isnull())
# Out:
#    employee_id   name  department  salary
# 0        False  False       False   False
# 1        False  False       False   False
# 2        False  False       False   False
# 3        False  False        True   False
# 4        False  False       False   False
# 5        False  False       False   False
# 6        False  False       False    True
# 7        False  False       False   False
# 8        False  False       False   False
# 9        False  False       False   False

# %%
print(df.isnull().sum())
# Out:
# employee_id    0
# name           0
# department     1
# salary         1
# dtype: int64

# %%
df.fillna(21)
# Out:
#    employee_id             name   department   salary
# 0          101      Alice Smith  Engineering  85000.0
# 1          102        Bob Jones    Marketing  62000.0
# 2          103    Charlie Brown      Finance      0.0
# 3          104     Diana Prince           21  75000.0
# 4          105      Evan Wright  Engineering  92000.0
# 5          106  Fiona Gallagher           HR  58000.0
# 6          107     George Clark    Marketing     21.0
# 7          108    Hannah Abbott      Finance      0.0
# 8          109      Ian Malcolm        Sales  81000.0
# 9          110    Julia Roberts           HR  67000.0

# %%
df.fillna("Not Available")
# Out:
#    employee_id             name     department         salary
# 0          101      Alice Smith    Engineering        85000.0
# 1          102        Bob Jones      Marketing        62000.0
# 2          103    Charlie Brown        Finance            0.0
# 3          104     Diana Prince  Not Available        75000.0
# 4          105      Evan Wright    Engineering        92000.0
# 5          106  Fiona Gallagher             HR        58000.0
# 6          107     George Clark      Marketing  Not Available
# 7          108    Hannah Abbott        Finance            0.0
# 8          109      Ian Malcolm          Sales        81000.0
# 9          110    Julia Roberts             HR        67000.0

# %%
df.fillna({"department":"HR","salary":50000})
# Out:
#    employee_id             name   department   salary
# 0          101      Alice Smith  Engineering  85000.0
# 1          102        Bob Jones    Marketing  62000.0
# 2          103    Charlie Brown      Finance      0.0
# 3          104     Diana Prince           HR  75000.0
# 4          105      Evan Wright  Engineering  92000.0
# 5          106  Fiona Gallagher           HR  58000.0
# 6          107     George Clark    Marketing  50000.0
# 7          108    Hannah Abbott      Finance      0.0
# 8          109      Ian Malcolm        Sales  81000.0
# 9          110    Julia Roberts           HR  67000.0

# %%
df["salary"]=df["salary"].fillna(df["salary"].median())
df["salary"]
# Out:
# 0    85000.0
# 1    62000.0
# 2        0.0
# 3    75000.0
# 4    92000.0
# 5    58000.0
# 6    67000.0
# 7        0.0
# 8    81000.0
# 9    67000.0
# Name: salary, dtype: float64

# %%
df["salary"]=df["salary"].fillna(df["salary"].mean())
df["salary"]
# Out:
# 0    85000.0
# 1    62000.0
# 2        0.0
# 3    75000.0
# 4    92000.0
# 5    58000.0
# 6    67000.0
# 7        0.0
# 8    81000.0
# 9    67000.0
# Name: salary, dtype: float64

# %%
df["department"]=df["department"].fillna(df["department"].mode())
df["department"]
# Out:
# 0    Engineering
# 1      Marketing
# 2        Finance
# 3      Marketing
# 4    Engineering
# 5             HR
# 6      Marketing
# 7        Finance
# 8          Sales
# 9             HR
# Name: department, dtype: str

# %%
import numpy as np
marks=np.array([99,92,45,85,93,57,84,65,85,67])
print(marks)
print(marks.ndim)
print(marks.shape)
print(marks.size)
print(marks.dtype)
print(type(marks))
print(marks.flatten())
print(marks.reshape(2,5))
# Out:
# [99 92 45 85 93 57 84 65 85 67]
# 1
# (10,)
# 10
# int32
# <class 'numpy.ndarray'>
# [99 92 45 85 93 57 84 65 85 67]
# [[99 92 45 85 93]
#  [57 84 65 85 67]]

# %%
import pandas as pd

# %%
df=pd.read_csv("people_data_with_nulls.csv")
print(df)
# Out:
#      person_id   first_name  last_name   age  gender  \
# 0    PID-10000      Kenneth     Wilson  36.0  Female
# 1    PID-10001       Donald      Davis  72.0  Female
# 2    PID-10002       Joseph  Rodriguez  63.0  Female
# 3    PID-10003        Linda      Perez  53.0  Female
# 4    PID-10004  Christopher  Hernandez  62.0  Female
# ..         ...          ...        ...   ...     ...
# 995  PID-10995        Linda      Lopez  54.0     NaN
# 996  PID-10996     Margaret   Gonzalez  50.0    Male
# 997  PID-10997         Mark     Harris  73.0  Female
# 998  PID-10998      William   Gonzalez  20.0    Male
# 999  PID-10999       Donald    Jackson  71.0  Female
#
#                                    email     phone_number           city  \
# 0                                    NaN  +1-779-246-9681     Fort Worth
# 1                                    NaN  +1-677-258-6308        Phoenix
# 2         joseph.rodriguez46@example.com  +1-614-438-1287        Houston
# ...

# %%
print(df.head())
# Out:
#    person_id   first_name  last_name   age  gender  \
# 0  PID-10000      Kenneth     Wilson  36.0  Female
# 1  PID-10001       Donald      Davis  72.0  Female
# 2  PID-10002       Joseph  Rodriguez  63.0  Female
# 3  PID-10003        Linda      Perez  53.0  Female
# 4  PID-10004  Christopher  Hernandez  62.0  Female
#
#                                  email     phone_number        city    income  \
# 0                                  NaN  +1-779-246-9681  Fort Worth  51046.39
# 1                                  NaN  +1-677-258-6308     Phoenix  43395.83
# 2       joseph.rodriguez46@example.com  +1-614-438-1287     Houston  60961.95
# 3            linda.perez91@example.com  +1-386-983-2161    Columbus  84127.46
# 4  christopher.hernandez15@outlook.com  +1-329-293-3363   San Diego  63305.65
#
#   employment_status
# 0          Employed
# 1          Employed
# 2          Employed
# 3          Employed
# 4               NaN

# %%
print(df.tail())
# Out:
#      person_id first_name last_name   age  gender  \
# 995  PID-10995      Linda     Lopez  54.0     NaN
# 996  PID-10996   Margaret  Gonzalez  50.0    Male
# 997  PID-10997       Mark    Harris  73.0  Female
# 998  PID-10998    William  Gonzalez  20.0    Male
# 999  PID-10999     Donald   Jackson  71.0  Female
#
#                              email     phone_number           city    income  \
# 995        linda.lopez68@gmail.com  +1-594-802-8095    San Antonio  36741.25
# 996  margaret.gonzalez44@yahoo.com  +1-611-174-1294    Los Angeles       NaN
# 997        mark.harris77@yahoo.com  +1-992-120-6330  San Francisco  46146.18
# 998    william.gonzalez9@yahoo.com  +1-759-185-4771         Dallas  38729.58
# 999   donald.jackson95@outlook.com  +1-571-579-2174     Fort Worth  22628.55
#
#     employment_status
# 995     Self-Employed
# 996          Employed
# 997          Employed
# 998     Self-Employed
# 999          Employed

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   person_id          1000 non-null   str
#  1   first_name         1000 non-null   str
#  2   last_name          1000 non-null   str
#  3   age                916 non-null    float64
#  4   gender             951 non-null    str
#  5   email              868 non-null    str
#  6   phone_number       854 non-null    str
#  7   city               932 non-null    str
#  8   income             900 non-null    float64
#  9   employment_status  927 non-null    str
# dtypes: float64(2), str(8)
# memory usage: 46.9 KB
# None

# %%
print(df.describe())
# Out:
#               age         income
# count  916.000000     900.000000
# mean    45.640830   54349.719156
# std     16.301357   19032.989330
# min     18.000000   -8699.440000
# 25%     32.000000   41261.467500
# 50%     46.000000   54357.300000
# 75%     60.000000   66978.322500
# max     74.000000  113322.500000

# %%
print(df.shape)
# Out:
# (1000, 10)

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
print(df.columns)
# Out:
# Index(['person_id', 'first_name', 'last_name', 'age', 'gender', 'email',
#        'phone_number', 'city', 'income', 'employment_status'],
#       dtype='str')

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.plot(x,y)
plt.show()

# %%
students=["Amit","Rahul","Neha","Priya"]
marks=[83,66,56,76]
plt.plot(students,marks)
plt.title("student marks")
plt.show()

# %%
students=["Amit","Rahul","Neha","Priya"]
marks=[83,66,56,76]
plt.plot(students,marks)
plt.title("student marks")
plt.xlabel("students")
plt.ylabel("marks")
plt.show()

# %%
students=["Amit","Rahul","Neha","Priya"]
marks=[83,66,56,76]
plt.plot(students,marks,color="green",linewidth=2.5,linestyle="solid")
plt.title("student marks")
plt.xlabel("students")
plt.ylabel("marks")
plt.show()

# %%
students=["Amit","Rahul","Neha","Priya"]
marks=[83,66,56,76]
plt.plot(students,marks,color="green",linewidth=2.5,linestyle="dashed",marker="o")
plt.title("student marks")
plt.xlabel("students")
plt.ylabel("marks")
plt.show()

# %%
x=["A","B","C","D"]
y=[1,2,3,4]
plt.plot(x,y,color="blue",linewidth=1.5,linestyle="solid",marker="o")
plt.title("xy")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
students=["Amit","Rahul","Priya","Neha"]
marks=[83,95,74,76]
plt.bar(students,marks,color="green")
plt.show()

# %%
students=["Amit","Rahul","Priya","Neha"]
marks=[83,95,74,76]
plt.barh(students,marks)
# Out:
# <BarContainer object of 4 artists>

# %%
subjects = ["Math","Science","English"] 
marks = [40,35,25] 
plt.pie(marks, labels=subjects) 
plt.show()

# %%
hours = [1,2,3,4,5]
marks = [40,50,65,75,90]
plt.scatter(hours, marks)
plt.show()

# %%
marks = [45,55,67,78,88,67,78,90,45,55,67]
plt.hist(marks) 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data=np.array([
    [90,80,70],
    [60,75,74],
    [74,95,76],
    [84,7,83]
])
plt.imshow(data)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data=np.array([
    [90,80,70],
    [60,75,74],
    [74,95,76],
    [84,7,83]
])
plt.imshow(data)
plt.colorbar()
plt.show()
