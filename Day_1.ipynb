# %%
a=float(input("enter a number:"))
b=float(input("enter another number:"))
print("sum is:",a+b)
print("difference is:",a-b)
print("product is:",a*b)
print("quotient is:",a/b)
print("modulus is:",a%b)
# Out:
# enter a number: 10
# enter another number: 5
# sum is: 15.0
# difference is: 5.0
# product is: 50.0
# quotient is: 2.0
# modulus is: 0.0

# %%
a=float(input("enter a number:"))
b=float(input("enter another number:"))
print("sum is:",a+b)
print("difference is:",a-b)
print("product is:",a*b)
print("quotient is:",a/b)
print("modulus is:",a%b)
# Out:
# enter a number: 2
# enter another number: 3
# sum is: 5.0
# difference is: -1.0
# product is: 6.0
# quotient is: 0.6666666666666666
# modulus is: 2.0

# %%
name="Rahul"
print(name)
# Out:
# Rahul

# %%
age=20
print(age)
# Out:
# 20

# %%
l="length"
print(l)
# Out:
# length

# %%
Amount= 202.22
print(Amount)
# Out:
# 202.22

# %%
name="RAHUL"
print(name)
# Out:
# RAHUL

# %%
r="Rahul"
print(r.upper())
# Out:
# RAHUL

# %%
a="Rahul"
print(a.lower())
# Out:
# rahul

# %%
a="Rahul"
b="Sharma"
print(a+"   "+b)
# Out:
# Rahul   Sharma

# %%
name= "Helloworld"
print(name[0:5])
print(name[5::])
# Out:
# Hello
# world

# %%
city="Delhi6"
print(city)
# Out:
# Delhi6

# %%
a=True
b=False
print(a,b)
# Out:
# True False

# %%
a=10
b=9
print(a>b,a<b,a==b,a<=b,a>=b)
# Out:
# True False False False True

# %%
a=10
b=6
print("sum is:",a+b)
print("difference is:",a-b)
print("product is:",a*b)
print("quotient is:",a/b)
print("modulus is:",a%b)
# Out:
# sum is: 16
# difference is: 4
# product is: 60
# quotient is: 1.6666666666666667
# modulus is: 4

# %%
a=11.11
b=11.11
print("sum is:",a+b)
print("difference is:",a-b)
print("product is:",a*b)
print("quotient is:",a/b)
print("modulus is:",a%b)
# Out:
# sum is: 22.22
# difference is: 0.0
# product is: 123.43209999999999
# quotient is: 1.0
# modulus is: 0.0

# %%
a=10
b=9
print(a>b)
print(a<b)
print(a==b)
print(a<=b)
print(a>=b)
# Out:
# True
# False
# False
# False
# True

# %%
a=11.2
b=6.8
print(a>b)
print(a<b)
print(a==b)
print(a<=b)
print(a>=b)
# Out:
# True
# False
# False
# False
# True

# %%
print(10<9 and True)
print(10>8 and False)
print(10>6 and True)
print(10<9 and False)
# Out:
# False
# False
# True
# False

# %%
age=20
if age>=18:
    print("Eligible to vote")
else:
    print("Not eligible to vote")
# Out:
# Eligible to vote

# %%
num=5
if num%2==0:
  print("even")
else:
  print("odd")
# Out:
# odd

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,6): 
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
a=float(input("enter your marks"))
if a>90 and a<80:
          print("Grade A")
elif a>80 and a<70:
    print("Grade B")
elif a>70 and a<60:
    print("Grade C")
else:
    print("Grade D")
# Out:
# enter your marks 79
# Grade D

# %%
rows=int(input("enter the number of rows"))
for i in range(rows):
    print(" "*(rows-i-1),end=" ")
    print("*"*(2*i+1))
# Out:
# enter the number of rows 5
#      *
#     ***
#    *****
#   *******
#  *********
