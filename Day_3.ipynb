# %%
file = open("cities.txt","r")
print(file.read())
file.close()
# Out:
# Kanpur
# Mumbai
# Delhi
# Kolkata
# Chennai
# Bengaluru
# Hyderabad
# Pune
# Ahmedabad
# Jaipur
# Lucknow
# Kanpur
# Nagpur
# Indore
# Bhopal
# Patna
# Ranchi
# Raipur
# Bhubaneswar
# Guwahati
# Chandigarh
# Amritsar
# Ludhiana
# Jalandhar
# Shimla
# Dehradun
# Srinagar
# Agra
# Varanasi
# Prayagraj
# Meerut
# Noida
# Gurugram
# Faridabad
# Surat
# Vadodara
# Rajkot
# Nashik
# Aurangabad
# Visakhapatnam
# Vijayawada
# Tirupati
# Kochi
# Thiruvananthapuram
# Kozhikode
# Mysuru
# Mangaluru
# Coimbatore
# Madurai
# Jodhpur

# %%
file = open("cities.txt","r")
data=file.read()
print(data)
file.close()
# Out:
# Kanpur
# Mumbai
# Delhi
# Kolkata
# Chennai
# Bengaluru
# Hyderabad
# Pune
# Ahmedabad
# Jaipur
# Lucknow
# Kanpur
# Nagpur
# Indore
# Bhopal
# Patna
# Ranchi
# Raipur
# Bhubaneswar
# Guwahati
# Chandigarh
# Amritsar
# Ludhiana
# Jalandhar
# Shimla
# Dehradun
# Srinagar
# Agra
# Varanasi
# Prayagraj
# Meerut
# Noida
# Gurugram
# Faridabad
# Surat
# Vadodara
# Rajkot
# Nashik
# Aurangabad
# Visakhapatnam
# Vijayawada
# Tirupati
# Kochi
# Thiruvananthapuram
# Kozhikode
# Mysuru
# Mangaluru
# Coimbatore
# Madurai
# Jodhpur

# %%
class Myemptyclass:
    pass

# %%
class product:
    def _init_(self,name,price,quantity):
        self.name=name
        self.price=price
        self.quantity=quantity

# %%
class student:
    def display(self):
        print("Welcome to python")
s1 = student()
s1.display()
# Out:
# Welcome to python

# %%
class student:
    def name(self):
        print("Welcome to python")
    def roll(self):
        print("Hello")
s1=student()
s2=student()
s1.name()
s2.roll()
# Out:
# Welcome to python
# Hello

# %%
class student:
    def display(self):
        print("student name:",self.name)
        print("roll_no:",self.roll_no)
        print("marks:",self.marks)
        print("course:",self.course)

student1=student()
student2=student()
student3=student()
student4=student()

student1.name="sneha"
student1.roll_no=104
student1.marks=90
student1.course="Machine learning"

student2.name="Abhay"
student2.roll_no=102
student2.marks=95
student2.course="Data science"

student3.name="Priya"
student3.roll_no=103
student3.marks=97
student3.course="Artifical Intelligence"

student4.name="ram"
student4.roll_no=101
student4.marks=95
student4.course="Software development"

student1.display()
student2.display()
student3.display()
student4.display()
# Out:
# student name: sneha
# roll_no: 104
# marks: 90
# course: Machine learning
# student name: Abhay
# roll_no: 102
# marks: 95
# course: Data science
# student name: Priya
# roll_no: 103
# marks: 97
# course: Artifical Intelligence
# student name: ram
# roll_no: 101
# marks: 95
# course: Software development

# %%
a=float(input("enter a number"))
b=float(input("enter another number"))
a,b=b,a
print(a,b)
# Out:
# enter a number 2
# enter another number 3
# 3.0 2.0

# %%
# Parent Class (Base Class)

class Person:

    def _init_(self, name, age):
        self.name = name
        self.age = age

    def show_person(self):
        print("Name :", self.name)
        print("Age  :", self.age)


# Child Class (Derived Class)

class Student(Person):

    def __init__(self, name, age, roll_no, marks):
        # Call Parent Constructor
        super()._init_(name, age)

        # Child Class Variables
        self.roll_no = roll_no
        self.marks = marks

    def show_student(self):
        print("Roll Number :", self.roll_no)
        print("Marks       :", self.marks)
# Create Object

student1 = Student("shiv prakash shukla", 20, 101, 92)
# Display Data

print("Student Information")
print("--------------------")

student1.show_person()      # Parent Class Method
student1.show_student()     # Child Class Method
# Out:
# Student Information
# --------------------
# Name : shiv prakash shukla
# Age  : 20
# Roll Number : 101
# Marks       : 92

# %%
file= open("cities.txt","r")
print(file.read())
file.close()
# Out:
# Kanpur
# Mumbai
# Delhi
# Kolkata
# Chennai
# Bengaluru
# Hyderabad
# Pune
# Ahmedabad
# Jaipur
# Lucknow
# Kanpur
# Nagpur
# Indore
# Bhopal
# Patna
# Ranchi
# Raipur
# Bhubaneswar
# Guwahati
# Chandigarh
# Amritsar
# Ludhiana
# Jalandhar
# Shimla
# Dehradun
# Srinagar
# Agra
# Varanasi
# Prayagraj
# Meerut
# Noida
# Gurugram
# Faridabad
# Surat
# Vadodara
# Rajkot
# Nashik
# Aurangabad
# Visakhapatnam
# Vijayawada
# Tirupati
# Kochi
# Thiruvananthapuram
# Kozhikode
# Mysuru
# Mangaluru
# Coimbatore
# Madurai
# Jodhpur

# %%
file=open("cities.txt","r")
print(file.readline())
file.close()
# Out:
# Kanpur

# %%
file=open("cities.txt","r")
print(file.readlines())
file.close()
# Out:
# ['Kanpur\n', 'Mumbai\n', 'Delhi\n', 'Kolkata\n', 'Chennai\n', 'Bengaluru\n', 'Hyderabad\n', 'Pune\n', 'Ahmedabad\n', 'Jaipur\n', 'Lucknow\n', 'Kanpur\n', 'Nagpur\n', 'Indore\n', 'Bhopal\n', 'Patna\n', 'Ranchi\n', 'Raipur\n', 'Bhubaneswar\n', 'Guwahati\n', 'Chandigarh\n', 'Amritsar\n', 'Ludhiana\n', 'Jalandhar\n', 'Shimla\n', 'Dehradun\n', 'Srinagar\n', 'Agra\n', 'Varanasi\n', 'Prayagraj\n', 'Meerut\n', 'Noida\n', 'Gurugram\n', 'Faridabad\n', 'Surat\n', 'Vadodara\n', 'Rajkot\n', 'Nashik\n', 'Aurangabad\n', 'Visakhapatnam\n', 'Vijayawada\n', 'Tirupati\n', 'Kochi\n', 'Thiruvananthapuram\n', 'Kozhikode\n', 'Mysuru\n', 'Mangaluru\n', 'Coimbatore\n', 'Madurai\n', 'Jodhpur']

# %%
print(0.1+0.2==0.3)
# Out:
# False

# %%
import keyword 
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
a=0.1
b=0.2
print(a+b)
# Out:
# 0.30000000000000004

# %%
a=3
for i in range(0,3):
    print(i)
# Out:
# 0
# 1
# 2
